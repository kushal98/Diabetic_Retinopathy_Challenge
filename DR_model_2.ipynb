# %%
import os
import pandas as pd
import numpy as np

# %%
import tensorflow as tf

# %%
os.listdir("./retinopathy detection dataset/")
# Out:
# ['resized_train_1',
#  'sample.zip',
#  'sampleSubmission.csv.zip',
#  'train',
#  'train.zip.001',
#  'train.zip.002',
#  'train.zip.003',
#  'train.zip.004',
#  'train.zip.005',
#  'trainLabels.csv',
#  'trainLabels.csv.zip',
#  'train_1',
#  'train_2',
#  'train_3',
#  'train_4']

# %%
train_labels = pd.read_csv('./retinopathy detection dataset/trainLabels.csv')

# %%
np.size(os.listdir("./retinopathy detection dataset/train_2"))
# Out:
# 3160

# %%
np.size(os.listdir("./retinopathy detection dataset/train"))
# Out:
# 15200

# %%
np.size(os.listdir("./retinopathy detection dataset/train_4"))
# Out:
# 6110

# %%
np.size(os.listdir("./retinopathy detection dataset/train_3"))
# Out:
# 5125

# %%
from PIL import Image
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image

# %%
lst = os.listdir("./retinopathy detection dataset/train_2")
np.size(lst)
# Out:
# 3160

# %%
immatrix = []
imlabels = []

# %%
rows,cols = 224,224

# %%
import cv2
from tqdm import tqdm

for file in tqdm(lst):
    base = os.path.basename("./retinopathy detection dataset/train_2/" + file)
    print(file)
    fileName = os.path.splitext(base)[0]
    imlabels.append(train_labels.loc[train_labels.image==fileName, 'level'].values[0])
    im = cv2.imread("./retinopathy detection dataset/train_2/" + file)   
    img = cv2.resize(im,(rows,cols))
    immatrix.append(np.array(img))
# Out:
#   0%|                                                                                         | 0/3160 [00:00<?, ?it/s]
# 10003_left.jpeg
#   0%|                                                                                 | 1/3160 [00:00<15:35,  3.38it/s]
# 10003_right.jpeg
#   0%|                                                                                 | 2/3160 [00:00<15:31,  3.39it/s]
# 10007_left.jpeg
#   0%|                                                                                 | 3/3160 [00:00<13:28,  3.90it/s]
# 10007_right.jpeg
#   0%|                                                                                 | 4/3160 [00:00<11:44,  4.48it/s]
# 10009_left.jpeg
#   0%|▏                                                                                | 5/3160 [00:01<11:27,  4.59it/s]
# 10009_right.jpeg
#   0%|▏                                                                                | 6/3160 [00:01<11:24,  4.61it/s]
# 10010_left.jpeg
# ...

# %%
immatrix = np.asarray(immatrix)
imlabels = np.asarray(imlabels)

# %%
from sklearn.utils import shuffle
with tf.device("/gpu:0"):
    data,Label = shuffle(immatrix,imlabels, random_state=2)
    train_data = [data,Label]
    type(train_data)

# %%
(X,y) = (train_data[0],train_data[1])

# %%
y.shape
# Out:
# (3160,)

# %%
from keras.utils import np_utils

n_classes = 5

y = np_utils.to_categorical(y, n_classes)

# %%
from keras.models import Model
from keras import optimizers
from keras.models import model_from_json

# %%
json_file = open('model_train_1.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
loaded_model.load_weights("DR_train_1.h5")

# %%
loaded_model.compile(loss='binary_crossentropy', optimizer=optimizers.SGD(lr=1e-5, momentum=0.9), metrics=['accuracy'])

# %%
with tf.device("/gpu:0"):
    probs = loaded_model.predict(X)

# %%
from keras.applications.vgg16 import VGG16
base_model = VGG16(weights='imagenet',include_top=False, input_shape=(224,224,3))
